# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # printing strings

# %%
print("insert a cell below with B"), print('insert a cell above with A')
# Out:
# insert a cell below with B
# insert a cell above with A
# (None, None)

# %%
print('today','is a good day', sep=',')
# Out:
# today,is a good day

# %%
print('good morning', end = ' ')
print('brandon')
# Out:
# good morning brandon

# %%
print('Name: '+ "Brendon " + 'Krakowsky'), print('Name:','Brendon','Krakowsky'), print('Brendon\'s')
# Out:
# Name: Brendon Krakowsky
# Name: Brendon Krakowsky
# Brendon's
# (None, None, None)

# %% [markdown]
# # Types

# %%
type(99), type(2.1), type('susi')
# Out:
# (int, float, str)

# %% [markdown]
# # Operators

# %%
(3/2),(3.1/2)
# Out:
# (1.5, 1.55)

# %%
(3//2), (3.1//2)
# Out:
# (1, 1.0)

# %%
(3%2), (4%2), (3.1%2)
# Out:
# (1, 0, 1.1)

# %% [markdown]
# # **Boolien = every object has boolean value **

# %%
1==2, 1<2, 1.2==1.2, 'car' == 'car', 'Car' == 'car', '1'!=1
# Out:
# (False, True, True, True, False, True)

# %%
bool(False), bool(True), bool(7), bool(0), bool(7 == 0)
# Out:
# (False, True, True, False, False)

# %% [markdown]
# # **Finding out if a number is equal or not **

# %%
500002 % 2 == 0, 500003 % 2 >= 1
# Out:
# (True, True)

# %% [markdown]
# # Casting

# %%
12374/621, int(12374/621), round(12374/621)
# Out:
# (19.925925925925927, 19, 20)

# %%
print(4/2), print('4 % 2 =', 4%2), int('1')
# Out:
# 2.0
# 4 % 2 = 0
# (None, None, 1)

# %%
print('4 % 2 = '+ str(4%2)), print('is 4 even?' + str(4 % 2 ==0))
# Out:
# 4 % 2 = 0
# is 4 even?True
# (None, None)
